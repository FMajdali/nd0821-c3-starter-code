# %%
import pandas as pd
import joblib
from pathlib import Path
from ml.data import process_data
from ml.model import compute_model_metrics

# %%
current_script_dir = Path.cwd()
model_path = current_script_dir.parent / "model" / "random_forest_model.joblib"
model = joblib.load(model_path)

encoder_path = current_script_dir.parent / "model" / "encoder.joblib"
encoder = joblib.load(encoder_path)

# %%
data = pd.read_csv(current_script_dir.parent / "data" / "census.csv")
data.columns = [col.strip() for col in data.columns]

# %%
def slice_eval(data,cat_col,model,encoder,y_label = "salary"):
    if cat_col not in data.columns:
        return None

    cat_features = [
        "workclass",
        "education",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "native-country",
        ]
    
    x, y, encoder, lb = process_data(
            data, categorical_features=cat_features, label=y_label, training=True,encoder=encoder
        )

    encoded_df = pd.DataFrame(
        x,
        columns=encoder.get_feature_names_out(["color"])
    )
    """
    for indx,temp_df in data.groupby(cat_col):



        # Proces the test data with the process_data function.


        y_pred = model.predict(x)
        y_pred = lb.transform(y_pred)

        precision, recall, fbeta = compute_model_metrics(y, y_pred)

        print(f"The metrics of the category {data[cat_col].iloc[0]} from the feature {cat_col}:")
        print(precision, recall, fbeta)
    """

# %%
x, y, encoder, lb = process_data(
        data, categorical_features=cat_features, label="salary", training=True,encoder=encoder
    )

encoded_df = pd.DataFrame(
    x,
    columns=encoder.get_feature_names_out()
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 5
#       1 x, y, encoder, lb = process_data(
#       2         data, categorical_features=cat_features, label="salary", training=True,encoder=encoder
#       3     )
#       4
# ----> 5 encoded_df = pd.DataFrame(
#       6     x,
#       7     columns=encoder.get_feature_names_out()
#       8 )
#
# File /opt/conda/envs/ml/lib/python3.13/site-packages/pandas/core/frame.py:831, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     827                     typ=manager,
#     828                     copy=_copy,
#     829                 )
#     830             else:
# --> 831                 mgr = ndarray_to_mgr(
#     832                     data,
#     833                     index,
#     834                     columns,
#
# ...

# %%
cat_features = [
        "workclass",
        "education",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "native-country",
        ]
[w for w in encoder.get_feature_names_out(cat_features) if "sex" in w]
# Out:
# ['sex_ Female', 'sex_ Male']

# %%
slice_eval(data,'sex',model,encoder,y_label = "salary")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 slice_eval(data,'sex',model,encoder,y_label = "salary")
#
# Cell In[33], line 23, in slice_eval(data, cat_col, model, encoder, y_label)
#      19         x, y, encoder, lb = process_data(
#      20             temp_df, categorical_features=cat_features, label=y_label, training=True,encoder=encoder
#      21         )
#      22
# ---> 23         y_pred = model.predict(x)
#      24         y_pred = lb.transform(y_pred)
#      25
#      26         precision, recall, fbeta = compute_model_metrics(y, y_pred)
#
# File /opt/conda/envs/ml/lib/python3.13/site-packages/sklearn/ensemble/_forest.py:903, in ForestClassifier.predict(self, X)
#     882 def predict(self, X):
#     883     """
#     884     Predict class for X.
#     885
#    (...)    901         The predicted classes.
#     902     """
# ...

# %%
data["sex"].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64
